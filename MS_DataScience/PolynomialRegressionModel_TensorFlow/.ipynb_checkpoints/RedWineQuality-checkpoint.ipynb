# %% [markdown]
# # Predicting Red Wine Quality using Polynomial Regression

# %% [markdown]
# ### Red Wine Quality Data
#
# The objective of this analysis is to predict the red wine quality using a polynomial regression model.
#
# Input variables:
# 1. fixed acidity
# 2. volatile acidity
# 3. citric acid
# 4. residual sugar
# 5. chlorides
# 6. free sulfur dioxide
# 7. total sulfur dioxide
# 8. density
# 9. pH
# 10. sulphates
# 11. alcohol
#
# Variable to predict:
# 12. quality (score between 0 and 10)

# %% [markdown]
# ## Loading libraries and data set of red wine quality

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
data = pd.read_csv('winequality-red.csv')

# %% [markdown]
# Example of the first 10 rows of the wine data

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %% [markdown]
# ## Exploratory Analysis

# %% [markdown]
# Split train and test data

# %%
index = np.random.rand(len(data)) < 0.8

# %%
train = data[index]
test = data[~index]

# %%
train.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1252.000000       1252.000000  1252.000000     1252.000000
# mean        8.343850          0.525779     0.273658        2.551837
# std         1.744825          0.177733     0.195534        1.434695
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.300000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.400000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1252.000000          1252.000000           1252.000000  1252.000000
# mean      0.087649            15.828674             46.536342     0.996757
# std       0.047518            10.462869             33.000110     0.001900
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.071000             7.000000             22.000000     0.995600
# 50%       0.080000            13.000000             38.000000     0.996775
# 75%       0.091000            21.000000             63.000000     0.997833
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1252.000000  1252.000000  1252.000000  1252.000000
# mean      3.307412     0.656645    10.425479     5.640575
# std       0.155468     0.172504     1.083398     0.817602
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.100000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %% [markdown]
# ### Distplots

# %%
plt.figure(figsize=(12,12))
sns.set_style("whitegrid")
grid = plt.GridSpec(6, 2, wspace=0.2, hspace=0.6)
plt.subplot(grid[0, 0:])
sns.distplot(train['fixed acidity'], color="green", axlabel="Fixed Acidity")
plt.subplot(grid[1, 0])
sns.distplot(train['volatile acidity'], color="red", axlabel="Volatile Acidity")
plt.subplot(grid[1, 1])
sns.distplot(train['citric acid'], color="blue", axlabel="Citric Acid")
plt.subplot(grid[2, 0])
sns.distplot(train['residual sugar'], color="orange", axlabel="Residual Sugar")
plt.subplot(grid[2, 1])
sns.distplot(train['chlorides'], color="brown", axlabel="Chlorides")
plt.subplot(grid[3, 0])
sns.distplot(train['free sulfur dioxide'], color="purple", axlabel="Free Sulfur Dioxide")
plt.subplot(grid[3, 1])
sns.distplot(train['density'], color="green", axlabel="Density")
plt.subplot(grid[4, 0])
sns.distplot(train['pH'], color="red", axlabel="pH")
plt.subplot(grid[4, 1])
sns.distplot(train['sulphates'], color="blue", axlabel="Sulphates")
plt.subplot(grid[5, 0])
sns.distplot(train['alcohol'], color="orange", axlabel="Alcohol")
plt.subplot(grid[5, 1])
sns.distplot(train['quality'], color="brown", axlabel="Quality")

# %% [markdown]
# ### Correlation Analysis

# %%
plt.figure(figsize=(12,12))
grid = plt.GridSpec(5, 2, wspace=0.2, hspace=1)
plt.subplot(grid[0, 0])
plt.scatter(x=train['fixed acidity'], y=train['quality'])
plt.title('Fixed Acidity vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['fixed acidity'], y=train['quality'])[0,1],4)))
plt.xlabel('Fixed Acidity')
plt.ylabel('Quality')
plt.subplot(grid[0, 1])
plt.scatter(x=train['volatile acidity'], y=train['quality'])
plt.title('Volatile Acidity vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['volatile acidity'], y=train['quality'])[0,1],4)))
plt.xlabel('Volatile Acidity')
plt.ylabel('Quality')
plt.subplot(grid[1, 0])
plt.scatter(x=train['citric acid'], y=train['quality'])
plt.title('Citric Acid vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['citric acid'], y=train['quality'])[0,1],4)))
plt.xlabel('Citric Acid')
plt.ylabel('Quality')
plt.subplot(grid[1, 1])
plt.scatter(x=train['residual sugar'], y=train['quality'])
plt.title('Residual Sugar vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['residual sugar'], y=train['quality'])[0,1],4)))
plt.xlabel('Residual Sugar')
plt.ylabel('Quality')
plt.subplot(grid[2, 0])
plt.scatter(x=train['chlorides'], y=train['quality'])
plt.title('Chlorides vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['chlorides'], y=train['quality'])[0,1],4)))
plt.xlabel('Chlorides')
plt.ylabel('Quality')
plt.subplot(grid[2, 1])
plt.scatter(x=train['free sulfur dioxide'], y=train['quality'])
plt.title('Free Sulfur Dioxide vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['free sulfur dioxide'], y=train['quality'])[0,1],4)))
plt.xlabel('Free Sulfur Dioxide')
plt.ylabel('Quality')
plt.subplot(grid[3, 0])
plt.scatter(x=train['density'], y=train['quality'])
plt.title('Density vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['density'], y=train['quality'])[0,1],4)))
plt.xlabel('Density')
plt.ylabel('Quality')
plt.subplot(grid[3, 1])
plt.scatter(x=train['pH'], y=train['quality'])
plt.title('pH vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['pH'], y=train['quality'])[0,1],4)))
plt.xlabel('pH')
plt.ylabel('Quality')
plt.subplot(grid[4, 0])
plt.scatter(x=train['sulphates'], y=train['quality'])
plt.title('Sulphates vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['sulphates'], y=train['quality'])[0,1],4)))
plt.xlabel('Sulphates')
plt.ylabel('Quality')
plt.subplot(grid[4, 1])
plt.scatter(x=train['alcohol'], y=train['quality'])
plt.title('Alcohol vs. Quality - Correlation of ' + 
          str(np.round(np.corrcoef(x=train['alcohol'], y=train['quality'])[0,1],4)))
plt.xlabel('Alcohol')
plt.ylabel('Quality')
# Out:
# Text(0, 0.5, 'Quality')

# %% [markdown]
# We can see that the variables ***Alcohol*** and ***Volatile Acidity*** have the highest correlation coefficients. These are going to be the main variables for the model.

# %% [markdown]
# ## Defining the function to build the polynomial model

# %%
def polynomial_model(epochs, lr, x_model, y_model, W_model, b_model, k):
    
    tf.reset_default_graph()
    
    #Hyperparameters
    epochs = epochs #parameter of the function
    lr = lr #parameter of the function
    m = x_model.shape[1] #parameter of the function for the number of columns of x matrix
    
    #Model variables
    X = tf.placeholder('float64', name = 'X')
    Y = tf.placeholder('float64', name = 'y')
    k = k #parameter of the function: prints every k
    
    #Learnable parameters
    W = tf.Variable(W_model, name = 'W')
    b = tf.Variable(b_model, name = 'b')
    
    #Hypothesis
    with tf.name_scope('Hypothesis'):
        y_hat = tf.add(tf.matmul(X, W, name = 'Matrix_Product'), b, name = 'Hypothesis_Product')

    #Mean Squared Error for Cost Function - J(m,b)
    with tf.name_scope('Cost_Function'):
        error = tf.reduce_mean(tf.square(y_hat-Y)) / 2

    #Gradient Descent
    with tf.name_scope('Gradient'):
        optimizer = tf.train.GradientDescentOptimizer(lr).minimize(error)

    #Creating the error summary
    error_summary = tf.summary.scalar(name='Error_Summary', tensor=error)
    
    graph_dir = (
        './graphs/graph_epochs='+str(epochs)+
        'lr='+str(lr)+
        'polynomial_degree=2'
    )
    
    with tf.Session() as sess:
        tf.initialize_all_variables().run()
        print('Variables successfully initialized')
        writer = tf.summary.FileWriter(graph_dir, sess.graph)
        print('Directory created in', graph_dir)
        for epoch in range(epochs):
            sess.run(optimizer, feed_dict={X : x_model, Y : y_model})
            if (epoch+1)%k == 0:
                e_summary = sess.run(error_summary, feed_dict = {X : x_model, Y : y_model})
                e = sess.run(error, feed_dict = {X : x_model, Y : y_model})
                writer.add_summary(e_summary, epoch)
                print(
                    'Epoch', epoch+1, ': \n',
                    'Bias = ', sess.run(b)
                )
                for i in range(0, m):
                    print(
                        'Variable', i+1, ' = ', sess.run(W)[i]
                    )
                print('error = ', '{:,}'.format(e))
                print('\n')
        writer.close()
    sess.close()

# %% [markdown]
# ## Transforming x and y to build input matrix

# %%
#For x variables
#Volatile Acidity and Alcohol
x1 = train['volatile acidity'].values
x2 = train['alcohol'].values
x_dict = {'var1': x1,
          'var2': x2, 
          'var3': x1**2, 
          'var4': x2**2, 
          'var5': x1*x2, 
          'var6': (x1**2)*x2, 
          'var7': x1*(x2**2), 
          'var8': (x1**2)*(x2**2)}
x_train = pd.DataFrame(x_dict)
print('x tensor shape:', x_train.shape)

#For y variable
y_train = train['quality'].values.reshape(len(train['quality']),1)
print('y tensor shape:', y_train.shape)
# Out:
# x tensor shape: (1252, 8)
# y tensor shape: (1252, 1)

# %% [markdown]
# ## Initial values for Weights and Bias

# %% [markdown]
# Each variable defined in the previous transformation needs to have an initial weight. The same for the bias.

# %%
#To initialize weights
w_train = np.random.rand(x_train.shape[1],1)*10
print('Weights:')
for i in range(0,len(w_train)):
    print('Variable ', i+1, ' Initial Weight: ', w_train[i], sep = '')
#To initialize weights
b_train = (np.random.rand(1)*10).reshape(1,1)
print('Bias:', b_train[0])
# Out:
# Weights:
# Variable 1 Initial Weight: [8.36081124]
# Variable 2 Initial Weight: [4.71996389]
# Variable 3 Initial Weight: [1.59025377]
# Variable 4 Initial Weight: [7.90799075]
# Variable 5 Initial Weight: [0.18945408]
# Variable 6 Initial Weight: [6.34577783]
# Variable 7 Initial Weight: [4.69026898]
# Variable 8 Initial Weight: [6.29256567]
# Bias: [6.45470499]

# %% [markdown]
# ## Graph of the Model using Gradient Descent Optimizer
# <img src="GraphTB_Polynomial.png">

# %% [markdown]
# ## Model 1
#
# - epochs = 1000
# - lr = 0.01
# - degree = 2

# %%
polynomial_model(
    epochs = 1000, 
    lr = 0.01,
    x_model = x_train,
    y_model = y_train,
    W_model = w_train,
    b_model = b_train,
    k = 50
)
# Out:
# Variables successfully initialized
# Directory created in ./graphs/graph_epochs=1000lr=0.01polynomial_degree=2
# Epoch 50 :
#  Bias =  [[5.59233367e+110]]
# Variable 1  =  [3.01216472e+110]
# Variable 2  =  [5.94360108e+111]
# Variable 3  =  [1.81567547e+110]
# Variable 4  =  [6.39129026e+112]
# Variable 5  =  [3.17624995e+111]
# Variable 6  =  [1.90463028e+111]
# Variable 7  =  [3.38717401e+112]
# Variable 8  =  [2.01932057e+112]
# error =  4.934141189713318e+229
#
#
# Epoch 100 :
#  Bias =  [[3.80888999e+222]]
# Variable 1  =  [2.05155928e+222]
# Variable 2  =  [4.04813518e+223]
# Variable 3  =  [1.23664082e+222]
# Variable 4  =  [4.3530524e+224]
# Variable 5  =  [2.16331631e+223]
# Variable 6  =  [1.29722717e+223]
# Variable 7  =  [2.30697486e+224]
# Variable 8  =  [1.37534174e+224]
# error =  inf
#
#
# Epoch 150 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 200 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 250 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 300 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 350 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 400 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 450 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 500 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 550 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 600 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 650 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 700 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 750 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 800 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 850 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 900 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 950 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 1000 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan

# %% [markdown]
# ### Results from Model 1
# <img src="lr0.01.png">

# %% [markdown]
# ## Model 2
#
# - epochs = 1000
# - lr = 0.001
# - degree = 2

# %%
polynomial_model(
    epochs = 1000, 
    lr = 0.001,
    x_model = x_train,
    y_model = y_train,
    W_model = w_train,
    b_model = b_train,
    k = 50
)
# Out:
# Variables successfully initialized
# Directory created in ./graphs/graph_epochs=1000lr=0.001polynomial_degree=2
# Epoch 50 :
#  Bias =  [[3.83427711e+59]]
# Variable 1  =  [2.06523339e+59]
# Variable 2  =  [4.07511692e+60]
# Variable 3  =  [1.24488332e+59]
# Variable 4  =  [4.38206648e+61]
# Variable 5  =  [2.17773531e+60]
# Variable 6  =  [1.30587349e+60]
# Variable 7  =  [2.32235138e+61]
# Variable 8  =  [1.3845087e+61]
# error =  2.3194895205026416e+127
#
#
# Epoch 100 :
#  Bias =  [[1.79052039e+120]]
# Variable 1  =  [9.64417125e+119]
# Variable 2  =  [1.90298712e+121]
# Variable 3  =  [5.81332256e+119]
# Variable 4  =  [2.0463256e+122]
# Variable 5  =  [1.01695296e+121]
# Variable 6  =  [6.09813282e+120]
# Variable 7  =  [1.08448539e+122]
# Variable 8  =  [6.46534143e+121]
# error =  5.05805984852834e+248
#
#
# Epoch 150 :
#  Bias =  [[8.36132388e+180]]
# Variable 1  =  [4.5036091e+180]
# Variable 2  =  [8.88651796e+181]
# Variable 3  =  [2.7146897e+180]
# Variable 4  =  [9.55587613e+182]
# Variable 5  =  [4.74893955e+181]
# Variable 6  =  [2.84768963e+181]
# Variable 7  =  [5.06430063e+182]
# Variable 8  =  [3.01916772e+182]
# error =  inf
#
#
# Epoch 200 :
#  Bias =  [[3.90454849e+241]]
# Variable 1  =  [2.10308324e+241]
# Variable 2  =  [4.14980221e+242]
# Variable 3  =  [1.26769848e+241]
# Variable 4  =  [4.46237728e+243]
# Variable 5  =  [2.21764699e+242]
# Variable 6  =  [1.32980643e+242]
# Variable 7  =  [2.36491346e+243]
# Variable 8  =  [1.4098828e+243]
# error =  inf
#
#
# Epoch 250 :
#  Bias =  [[1.82333553e+302]]
# Variable 1  =  [9.82092144e+301]
# Variable 2  =  [1.93786345e+303]
# Variable 3  =  [5.91986421e+301]
# Variable 4  =  [2.08382892e+304]
# Variable 5  =  [1.03559082e+303]
# Variable 6  =  [6.20989422e+302]
# Variable 7  =  [1.10436092e+304]
# Variable 8  =  [6.58383272e+303]
# error =  inf
#
#
# Epoch 300 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 350 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 400 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 450 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 500 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 550 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 600 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 650 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 700 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 750 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 800 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 850 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 900 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 950 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan
#
#
# Epoch 1000 :
#  Bias =  [[nan]]
# Variable 1  =  [nan]
# Variable 2  =  [nan]
# Variable 3  =  [nan]
# Variable 4  =  [nan]
# Variable 5  =  [nan]
# Variable 6  =  [nan]
# Variable 7  =  [nan]
# Variable 8  =  [nan]
# error =  nan

# %% [markdown]
# ### Results from Model 2
# <img src="lr0.001.png">

# %% [markdown]
# ## Model 3
#
# - epochs = 1000
# - lr = 0.0001
# - degree = 2

# %%
polynomial_model(
    epochs = 1000, 
    lr = 0.0001,
    x_model = x_train,
    y_model = y_train,
    W_model = w_train,
    b_model = b_train,
    k = 50
)
# Out:
# Variables successfully initialized
# Directory created in ./graphs/graph_epochs=1000lr=0.0001polynomial_degree=2
# Epoch 50 :
#  Bias =  [[6.37459537]]
# Variable 1  =  [8.29777156]
# Variable 2  =  [3.92858204]
# Variable 3  =  [1.53875858]
# Variable 4  =  [0.07327056]
# Variable 5  =  [-0.44563486]
# Variable 6  =  [5.82053841]
# Variable 7  =  [-1.74291164]
# Variable 8  =  [0.89974519]
# error =  57.942735129545824
#
#
# Epoch 100 :
#  Bias =  [[6.36830301]]
# Variable 1  =  [8.29468942]
# Variable 2  =  [3.89492834]
# Variable 3  =  [1.53533422]
# Variable 4  =  [0.08438973]
# Variable 5  =  [-0.45923438]
# Variable 6  =  [5.79587668]
# Variable 7  =  [-1.675372]
# Variable 8  =  [0.76587594]
# error =  52.105774205365975
#
#
# Epoch 150 :
#  Bias =  [[6.3618262]]
# Variable 1  =  [8.29189649]
# Variable 2  =  [3.85884078]
# Variable 3  =  [1.53242738]
# Variable 4  =  [0.06370509]
# Variable 5  =  [-0.47002591]
# Variable 6  =  [5.77655501]
# Variable 7  =  [-1.58091429]
# Variable 8  =  [0.68729143]
# error =  48.63107313043577
#
#
# Epoch 200 :
#  Bias =  [[6.35534518]]
# Variable 1  =  [8.28906206]
# Variable 2  =  [3.82278217]
# Variable 3  =  [1.529581]
# Variable 4  =  [0.04388403]
# Variable 5  =  [-0.48127728]
# Variable 6  =  [5.75785202]
# Variable 7  =  [-1.49178215]
# Variable 8  =  [0.61491228]
# error =  45.549697732276
#
#
# Epoch 250 :
#  Bias =  [[6.3488674]]
# Variable 1  =  [8.28618395]
# Variable 2  =  [3.7868197]
# Variable 3  =  [1.52678295]
# Variable 4  =  [0.0255332]
# Variable 5  =  [-0.49301525]
# Variable 6  =  [5.73963758]
# Variable 7  =  [-1.4082883]
# Variable 8  =  [0.54733961]
# error =  42.81141343363709
#
#
# Epoch 300 :
#  Bias =  [[6.3423963]]
# Variable 1  =  [8.28326678]
# Variable 2  =  [3.75096732]
# Variable 3  =  [1.52403096]
# Variable 4  =  [0.00856839]
# Variable 5  =  [-0.50519909]
# Variable 6  =  [5.72188323]
# Variable 7  =  [-1.33007628]
# Variable 8  =  [0.48423409]
# error =  40.373185605873324
#
#
# Epoch 350 :
#  Bias =  [[6.33593497]]
# Variable 1  =  [8.28031499]
# Variable 2  =  [3.71523688]
# Variable 3  =  [1.52132307]
# Variable 4  =  [-0.00710322]
# Variable 5  =  [-0.51778938]
# Variable 6  =  [5.70456437]
# Variable 7  =  [-1.25679908]
# Variable 8  =  [0.42529988]
# error =  38.19746983672611
#
#
# Epoch 400 :
#  Bias =  [[6.32948629]]
# Variable 1  =  [8.27733272]
# Variable 2  =  [3.67963923]
# Variable 3  =  [1.51865743]
# Variable 4  =  [-0.02156858]
# Variable 5  =  [-0.53074939]
# Variable 6  =  [5.68765803]
# Variable 7  =  [-1.1881323]
# Variable 8  =  [0.37026114]
# error =  36.25150962644219
#
#
# Epoch 450 :
#  Bias =  [[6.32305289]]
# Variable 1  =  [8.27432381]
# Variable 2  =  [3.64418437]
# Variable 3  =  [1.51603234]
# Variable 4  =  [-0.0349089]
# Variable 5  =  [-0.54404486]
# Variable 6  =  [5.67114269]
# Variable 7  =  [-1.12377299]
# Variable 8  =  [0.31886031]
# error =  34.5067242736314
#
#
# Epoch 500 :
#  Bias =  [[6.31663722]]
# Variable 1  =  [8.27129186]
# Variable 2  =  [3.60888146]
# Variable 3  =  [1.51344618]
# Variable 4  =  [-0.0472]
# Variable 5  =  [-0.55764393]
# Variable 6  =  [5.65499823]
# Variable 7  =  [-1.06343821]
# Variable 8  =  [0.27085684]
# error =  32.938175042843426
#
#
# Epoch 550 :
#  Bias =  [[6.31024154]]
# Variable 1  =  [8.26824017]
# Variable 2  =  [3.57373893]
# Variable 3  =  [1.51089744]
# Variable 4  =  [-0.05851268]
# Variable 5  =  [-0.57151689]
# Variable 6  =  [5.63920581]
# Variable 7  =  [-1.00686371]
# Variable 8  =  [0.22602612]
# error =  31.524099602038458
#
#
# Epoch 600 :
#  Bias =  [[6.30386791]]
# Variable 1  =  [8.26517186]
# Variable 2  =  [3.53876446]
# Variable 3  =  [1.50838468]
# Variable 4  =  [-0.06891305]
# Variable 5  =  [-0.58563607]
# Variable 6  =  [5.62374778]
# Variable 7  =  [-0.9538027]
# Variable 8  =  [0.18415836]
# error =  30.245505998748087
#
#
# Epoch 650 :
#  Bias =  [[6.29751825]]
# Variable 1  =  [8.26208978]
# Variable 2  =  [3.50396511]
# Variable 3  =  [1.50590657]
# Variable 4  =  [-0.07846281]
# Variable 5  =  [-0.59997574]
# Variable 6  =  [5.6086076]
# Variable 7  =  [-0.90402471]
# Variable 8  =  [0.14505766]
# error =  29.0858185603858
#
#
# Epoch 700 :
#  Bias =  [[6.2911943]]
# Variable 1  =  [8.25899661]
# Variable 2  =  [3.46934729]
# Variable 3  =  [1.50346186]
# Variable 4  =  [-0.08721961]
# Variable 5  =  [-0.61451194]
# Variable 6  =  [5.59376981]
# Variable 7  =  [-0.85731447]
# Variable 8  =  [0.10854107]
# error =  28.03056907801271
#
#
# Epoch 750 :
#  Bias =  [[6.28489769]]
# Variable 1  =  [8.25589482]
# Variable 2  =  [3.43491684]
# Variable 3  =  [1.50104935]
# Variable 4  =  [-0.09523723]
# Variable 5  =  [-0.62922235]
# Variable 6  =  [5.5792199]
# Variable 7  =  [-0.81347096]
# Variable 8  =  [0.07443774]
# error =  27.0671274821657
#
#
# Epoch 800 :
#  Bias =  [[6.27862989]]
# Variable 1  =  [8.25278671]
# Variable 2  =  [3.4006791]
# Variable 3  =  [1.49866793]
# Variable 4  =  [-0.10256593]
# Variable 5  =  [-0.64408622]
# Variable 6  =  [5.56494427]
# Variable 7  =  [-0.77230643]
# Variable 8  =  [0.04258813]
# error =  26.18446696003302
#
#
# Epoch 850 :
#  Bias =  [[6.27239224]]
# Variable 1  =  [8.24967442]
# Variable 2  =  [3.36663885]
# Variable 3  =  [1.49631656]
# Variable 4  =  [-0.10925259]
# Variable 5  =  [-0.65908426]
# Variable 6  =  [5.5509302]
# Variable 7  =  [-0.73364552]
# Variable 8  =  [0.01284323]
# error =  25.372959109215795
#
#
# Epoch 900 :
#  Bias =  [[6.26618599]]
# Variable 1  =  [8.24655992]
# Variable 2  =  [3.33280047]
# Variable 3  =  [1.49399424]
# Variable 4  =  [-0.11534101]
# Variable 5  =  [-0.67419852]
# Variable 6  =  [5.53716575]
# Variable 7  =  [-0.69732445]
# Variable 8  =  [-0.0149361]
# error =  24.624195286650778
#
#
# Epoch 950 :
#  Bias =  [[6.26001226]]
# Variable 1  =  [8.24344504]
# Variable 2  =  [3.29916786]
# Variable 3  =  [1.49170004]
# Variable 4  =  [-0.12087207]
# Variable 5  =  [-0.68941231]
# Variable 6  =  [5.52363972]
# Variable 7  =  [-0.66319028]
# Variable 8  =  [-0.04087981]
# error =  23.930830802563978
#
#
# Epoch 1000 :
#  Bias =  [[6.25387207]]
# Variable 1  =  [8.24033148]
# Variable 2  =  [3.26574454]
# Variable 3  =  [1.48943308]
# Variable 4  =  [-0.12588394]
# Variable 5  =  [-0.70471011]
# Variable 6  =  [5.51034161]
# Variable 7  =  [-0.63110015]
# Variable 8  =  [-0.06510924]
# error =  23.286449037780255

# %% [markdown]
# ### Results from Model 3
# <img src="lr0.0001.png">

# %% [markdown]
# ## Model 4
#
# - epochs = 1000
# - lr = 0.00001
# - degree = 2

# %%
polynomial_model(
    epochs = 1000, 
    lr = 0.00001,
    x_model = x_train,
    y_model = y_train,
    W_model = w_train,
    b_model = b_train,
    k = 50
)
# Out:
# Variables successfully initialized
# Directory created in ./graphs/graph_epochs=1000lr=1e-05polynomial_degree=2
# Epoch 50 :
#  Bias =  [[6.37463205]]
# Variable 1  =  [8.31122282]
# Variable 2  =  [3.88088704]
# Variable 3  =  [1.55639476]
# Variable 4  =  [-0.98032699]
# Variable 5  =  [-0.32810471]
# Variable 6  =  [5.9929058]
# Variable 7  =  [-0.76707946]
# Variable 8  =  [2.57955668]
# error =  1,989.7818346582799
#
#
# Epoch 100 :
#  Bias =  [[6.37582818]]
# Variable 1  =  [8.30743009]
# Variable 2  =  [3.90285782]
# Variable 3  =  [1.5513238]
# Variable 4  =  [-0.63989425]
# Variable 5  =  [-0.36383318]
# Variable 6  =  [5.94165093]
# Variable 7  =  [-1.09881387]
# Variable 8  =  [2.059545]
# error =  980.5637538335795
#
#
# Epoch 150 :
#  Bias =  [[6.37645871]]
# Variable 1  =  [8.30472959]
# Variable 2  =  [3.91695917]
# Variable 3  =  [1.54772897]
# Variable 4  =  [-0.40500592]
# Variable 5  =  [-0.38878608]
# Variable 6  =  [5.90562673]
# Variable 7  =  [-1.32438081]
# Variable 8  =  [1.69769634]
# error =  498.6583818025653
#
#
# Epoch 200 :
#  Bias =  [[6.3766943]]
# Variable 1  =  [8.30278122]
# Variable 2  =  [3.92558006]
# Variable 3  =  [1.54515275]
# Variable 4  =  [-0.24350028]
# Variable 5  =  [-0.40632023]
# Variable 6  =  [5.88011236]
# Variable 7  =  [-1.47687497]
# Variable 8  =  [1.44498366]
# error =  268.42498705058887
#
#
# Epoch 250 :
#  Bias =  [[6.37665703]]
# Variable 1  =  [8.30135226]
# Variable 2  =  [3.93041491]
# Variable 3  =  [1.54328041]
# Variable 4  =  [-0.13268524]
# Variable 5  =  [-0.41873119]
# Variable 6  =  [5.86186051]
# Variable 7  =  [-1.57890886]
# Variable 8  =  [1.26768603]
# error =  158.31053723669623
#
#
# Epoch 300 :
#  Bias =  [[6.37643122]]
# Variable 1  =  [8.30028195]
# Variable 2  =  [3.93263433]
# Variable 3  =  [1.54189453]
# Variable 4  =  [-0.05688399]
# Variable 5  =  [-0.42760478]
# Variable 6  =  [5.84862777]
# Variable 7  =  [-1.64610413]
# Variable 8  =  [1.14250729]
# error =  105.52836876781527
#
#
# Epoch 350 :
#  Bias =  [[6.37607512]]
# Variable 1  =  [8.29945923]
# Variable 2  =  [3.93304703]
# Variable 3  =  [1.54084487]
# Variable 4  =  [-0.00526626]
# Variable 5  =  [-0.43403658]
# Variable 6  =  [5.83886428]
# Variable 7  =  [-1.68925284]
# Variable 8  =  [1.05335317]
# error =  80.11210510975073
#
#
# Epoch 400 :
#  Bias =  [[6.375629]]
# Variable 1  =  [8.29880736]
# Variable 2  =  [3.93221173]
# Variable 3  =  [1.54002768]
# Variable 4  =  [0.02964998]
# Variable 5  =  [-0.43878344]
# Variable 6  =  [5.83149929]
# Variable 7  =  [-1.71581052]
# Variable 8  =  [0.98910485]
# error =  67.7595858342649
#
#
# Epoch 450 :
#  Bias =  [[6.37512066]]
# Variable 1  =  [8.29827333]
# Variable 2  =  [3.93051441]
# Variable 3  =  [1.53937125]
# Variable 4  =  [0.05303364]
# Variable 5  =  [-0.44236822]
# Variable 6  =  [5.8257931]
# Variable 7  =  [-1.73092768]
# Variable 8  =  [0.94208076]
# error =  61.64474828067656
#
#
# Epoch 500 :
#  Bias =  [[6.3745693]]
# Variable 1  =  [8.29782054]
# Variable 2  =  [3.92822172]
# Variable 3  =  [1.53882605]
# Variable 4  =  [0.06845565]
# Variable 5  =  [-0.4451521]
# Variable 6  =  [5.82123464]
# Variable 7  =  [-1.73816238]
# Variable 8  =  [0.906974]
# error =  58.509665052750805
#
#
# Epoch 550 :
#  Bias =  [[6.37398821]]
# Variable 1  =  [8.29742368]
# Variable 2  =  [3.92551791]
# Variable 3  =  [1.53835787]
# Variable 4  =  [0.07838291]
# Variable 5  =  [-0.44738462]
# Variable 6  =  [5.81747085]
# Variable 7  =  [-1.73997258]
# Variable 8  =  [0.88011815]
# error =  56.7993815572801
#
#
# Epoch 600 :
#  Bias =  [[6.37338655]]
# Variable 1  =  [8.29706529]
# Variable 2  =  [3.92253025]
# Variable 3  =  [1.53794306]
# Variable 4  =  [0.08451964]
# Variable 5  =  [-0.44923812]
# Variable 6  =  [5.81425781]
# Variable 7  =  [-1.7380562]
# Variable 8  =  [0.85898016]
# error =  55.77172552291963
#
#
# Epoch 650 :
#  Bias =  [[6.37277067]]
# Variable 1  =  [8.29673329]
# Variable 2  =  [3.91934668]
# Variable 3  =  [1.53756529]
# Variable 4  =  [0.08804319]
# Variable 5  =  [-0.45083167]
# Variable 6  =  [5.81142698]
# Variable 7  =  [-1.73358612]
# Variable 8  =  [0.84180997]
# error =  55.072443689074085
#
#
# Epoch 700 :
#  Bias =  [[6.37214493]]
# Variable 1  =  [8.29641935]
# Variable 2  =  [3.91602795]
# Variable 3  =  [1.53721327]
# Variable 4  =  [0.08976686]
# Variable 5  =  [-0.45224751]
# Variable 6  =  [5.80886193]
# Variable 7  =  [-1.72737247]
# Variable 8  =  [0.8273984]
# error =  54.53242628768221
#
#
# Epoch 750 :
#  Bias =  [[6.37151238]]
# Variable 1  =  [8.29611771]
# Variable 2  =  [3.91261604]
# Variable 3  =  [1.53687921]
# Variable 4  =  [0.0902525]
# Variable 5  =  [-0.45354243]
# Variable 6  =  [5.80648221]
# Variable 7  =  [-1.71997479]
# Variable 8  =  [0.81490999]
# error =  54.07092788831373
#
#
# Epoch 800 :
#  Bias =  [[6.3708751]]
# Variable 1  =  [8.2958244]
# Variable 2  =  [3.90913996]
# Variable 3  =  [1.53655773]
# Variable 4  =  [0.08988821]
# Variable 5  =  [-0.45475565]
# Variable 6  =  [5.80423224]
# Variable 7  =  [-1.7117795]
# Variable 8  =  [0.80376744]
# error =  53.649377376953574
#
#
# Epoch 850 :
#  Bias =  [[6.37023454]]
# Variable 1  =  [8.29553666]
# Variable 2  =  [3.90561975]
# Variable 3  =  [1.53624509]
# Variable 4  =  [0.08894209]
# Variable 5  =  [-0.45591426]
# Variable 6  =  [5.80207359]
# Variable 7  =  [-1.70305342]
# Variable 8  =  [0.79357181]
# error =  53.24933272968427
#
#
# Epoch 900 :
#  Bias =  [[6.36959169]]
# Variable 1  =  [8.29525261]
# Variable 2  =  [3.90206926]
# Variable 3  =  [1.53593873]
# Variable 4  =  [0.0875993]
# Variable 5  =  [-0.45703694]
# Variable 6  =  [5.79997973]
# Variable 7  =  [-1.69398074]
# Variable 8  =  [0.78404738]
# error =  52.86195942949694
#
#
# Epoch 950 :
#  Bias =  [[6.36894726]]
# Variable 1  =  [8.29497094]
# Variable 2  =  [3.89849807]
# Variable 3  =  [1.53563687]
# Variable 4  =  [0.08598775]
# Variable 5  =  [-0.45813659]
# Variable 6  =  [5.7979323]
# Variable 7  =  [-1.68468858]
# Variable 8  =  [0.77500354]
# error =  52.48300879944503
#
#
# Epoch 1000 :
#  Bias =  [[6.36830172]]
# Variable 1  =  [8.29469075]
# Variable 2  =  [3.89491279]
# Variable 3  =  [1.53533828]
# Variable 4  =  [0.08419573]
# Variable 5  =  [-0.45922212]
# Variable 6  =  [5.79591862]
# Variable 7  =  [-1.67526461]
# Variable 8  =  [0.7663085]
# error =  52.11042129388688

# %% [markdown]
# ### Results from Model 4
# <img src="lr0.00001.png">

# %% [markdown]
# ## Model 5
#
# - epochs = 1000
# - lr = 0.000001
# - degree = 2

# %%
polynomial_model(
    epochs = 1000, 
    lr = 0.000001,
    x_model = x_train,
    y_model = y_train,
    W_model = w_train,
    b_model = b_train,
    k = 50
)
# Out:
# Variables successfully initialized
# Directory created in ./graphs/graph_epochs=1000lr=1e-06polynomial_degree=2
# Epoch 50 :
#  Bias =  [[6.4070778]]
# Variable 1  =  [8.33440057]
# Variable 2  =  [4.21511961]
# Variable 3  =  [1.57387183]
# Variable 4  =  [2.49440333]
# Variable 5  =  [-0.08844652]
# Variable 6  =  [6.17418338]
# Variable 7  =  [1.73361027]
# Variable 8  =  [4.4763775]
# error =  188,703.28852024302
#
#
# Epoch 100 :
#  Bias =  [[6.3873547]]
# Variable 1  =  [8.32304743]
# Variable 2  =  [4.00680651]
# Variable 3  =  [1.56658248]
# Variable 4  =  [0.2690683]
# Variable 5  =  [-0.20758417]
# Variable 6  =  [6.09796458]
# Variable 7  =  [0.46983682]
# Variable 8  =  [3.67131201]
# error =  35,686.871097217285
#
#
# Epoch 150 :
#  Bias =  [[6.37925917]]
# Variable 1  =  [8.31798387]
# Variable 2  =  [3.92203709]
# Variable 3  =  [1.56310001]
# Variable 4  =  [-0.62817335]
# Variable 5  =  [-0.26041382]
# Variable 6  =  [6.06167475]
# Variable 7  =  [-0.08699099]
# Variable 8  =  [3.28951674]
# error =  8,887.617864431075
#
#
# Epoch 200 :
#  Bias =  [[6.37600543]]
# Variable 1  =  [8.31555397]
# Variable 2  =  [3.88869254]
# Variable 3  =  [1.56122011]
# Variable 4  =  [-0.9728172]
# Variable 5  =  [-0.28548602]
# Variable 6  =  [6.0421911]
# Variable 7  =  [-0.34797256]
# Variable 8  =  [3.08584231]
# error =  4,042.033822880107
#
#
# Epoch 250 :
#  Bias =  [[6.37476456]]
# Variable 1  =  [8.31423306]
# Variable 2  =  [3.8767081]
# Variable 3  =  [1.56002321]
# Variable 4  =  [-1.08814258]
# Variable 5  =  [-0.29887732]
# Variable 6  =  [6.02986752]
# Variable 7  =  [-0.48454348]
# Variable 8  =  [2.95802135]
# error =  3,025.791743128399
#
#
# Epoch 300 :
#  Bias =  [[6.37435735]]
# Variable 1  =  [8.31338509]
# Variable 2  =  [3.87355207]
# Variable 3  =  [1.55912538]
# Variable 4  =  [-1.10889231]
# Variable 5  =  [-0.30729427]
# Variable 6  =  [6.02067683]
# Variable 7  =  [-0.56821725]
# Variable 8  =  [2.86335897]
# error =  2,687.535632704662
#
#
# Epoch 350 :
#  Bias =  [[6.37429236]]
# Variable 1  =  [8.3127445]
# Variable 2  =  [3.87400251]
# Variable 3  =  [1.55836603]
# Variable 4  =  [-1.09120603]
# Variable 5  =  [-0.31353674]
# Variable 6  =  [6.01293465]
# Variable 7  =  [-0.6288465]
# Variable 8  =  [2.78399933]
# error =  2,478.611378826047
#
#
# Epoch 400 :
#  Bias =  [[6.37436489]]
# Variable 1  =  [8.31220019]
# Variable 2  =  [3.87588499]
# Variable 3  =  [1.55767772]
# Variable 4  =  [-1.05845347]
# Variable 5  =  [-0.31877569]
# Variable 6  =  [6.0059336]
# Variable 7  =  [-0.67891324]
# Variable 8  =  [2.7124445]
# error =  2,302.8346472590774
#
#
# Epoch 450 :
#  Bias =  [[6.37448979]]
# Variable 1  =  [8.3117055]
# Variable 2  =  [3.87829553]
# Variable 3  =  [1.55703184]
# Variable 4  =  [-1.02034323]
# Variable 5  =  [-0.32350285]
# Variable 6  =  [5.99937378]
# Variable 7  =  [-0.72365604]
# Variable 8  =  [2.64551688]
# error =  2,142.7283898703904
#
#
# Epoch 500 :
#  Bias =  [[6.37463173]]
# Variable 1  =  [8.31124062]
# Variable 2  =  [3.88085975]
# Variable 3  =  [1.556416]
# Variable 4  =  [-0.9808896]
# Variable 5  =  [-0.32792658]
# Variable 6  =  [5.99312537]
# Variable 7  =  [-0.76529228]
# Variable 8  =  [2.58184199]
# error =  1,994.5505073713841
#
#
# Epoch 550 :
#  Bias =  [[6.37477615]]
# Variable 1  =  [8.31079696]
# Variable 2  =  [3.88342395]
# Variable 3  =  [1.5558246]
# Variable 4  =  [-0.941734]
# Variable 5  =  [-0.33213703]
# Variable 6  =  [5.98712965]
# Variable 7  =  [-0.80477855]
# Variable 8  =  [2.52079889]
# error =  1,856.9963863730272
#
#
# Epoch 600 :
#  Bias =  [[6.37491717]]
# Variable 1  =  [8.31037064]
# Variable 2  =  [3.88592639]
# Variable 3  =  [1.55525486]
# Variable 4  =  [-0.90352969]
# Variable 5  =  [-0.33617492]
# Variable 6  =  [5.98135767]
# Variable 7  =  [-0.84254461]
# Variable 8  =  [2.46208256]
# error =  1,729.2315928201142
#
#
# Epoch 650 :
#  Bias =  [[6.37505247]]
# Variable 1  =  [8.30995971]
# Variable 2  =  [3.88834355]
# Variable 3  =  [1.55470521]
# Variable 4  =  [-0.86651911]
# Variable 5  =  [-0.34006025]
# Variable 6  =  [5.9757931]
# Variable 7  =  [-0.87879947]
# Variable 8  =  [2.40552133]
# error =  1,610.546606430144
#
#
# Epoch 700 :
#  Bias =  [[6.37518126]]
# Variable 1  =  [8.30956308]
# Variable 2  =  [3.89066779]
# Variable 3  =  [1.5541746]
# Variable 4  =  [-0.83077447]
# Variable 5  =  [-0.3438043]
# Variable 6  =  [5.970425]
# Variable 7  =  [-0.91365901]
# Variable 8  =  [2.35100077]
# error =  1,500.2937366681847
#
#
# Epoch 750 :
#  Bias =  [[6.37530334]]
# Variable 1  =  [8.30918]
# Variable 2  =  [3.89289799]
# Variable 3  =  [1.5536622]
# Variable 4  =  [-0.7962981]
# Variable 5  =  [-0.34741456]
# Variable 6  =  [5.96524481]
# Variable 7  =  [-0.94719928]
# Variable 8  =  [2.29843184]
# error =  1,397.8733062609847
#
#
# Epoch 800 :
#  Bias =  [[6.3754188]]
# Variable 1  =  [8.30880989]
# Variable 2  =  [3.89503568]
# Variable 3  =  [1.5531673]
# Variable 4  =  [-0.76306414]
# Variable 5  =  [-0.35089688]
# Variable 6  =  [5.96024514]
# Variable 7  =  [-0.97947866]
# Variable 8  =  [2.24773759]
# error =  1,302.7286011270073
#
#
# Epoch 850 :
#  Bias =  [[6.37552778]]
# Variable 1  =  [8.30845223]
# Variable 2  =  [3.89708345]
# Variable 3  =  [1.55268923]
# Variable 4  =  [-0.73103598]
# Variable 5  =  [-0.3542563]
# Variable 6  =  [5.95541921]
# Variable 7  =  [-1.01054725]
# Variable 8  =  [2.19884757]
# error =  1,214.3425323280094
#
#
# Epoch 900 :
#  Bias =  [[6.37563051]]
# Variable 1  =  [8.30810657]
# Variable 2  =  [3.89904421]
# Variable 3  =  [1.55222738]
# Variable 4  =  [-0.70017348]
# Variable 5  =  [-0.35749746]
# Variable 6  =  [5.95076064]
# Variable 7  =  [-1.04045075]
# Variable 8  =  [2.15169539]
# error =  1,132.2347704549643
#
#
# Epoch 950 :
#  Bias =  [[6.37572718]]
# Variable 1  =  [8.30777245]
# Variable 2  =  [3.90092099]
# Variable 3  =  [1.55178117]
# Variable 4  =  [-0.6704359]
# Variable 5  =  [-0.36062469]
# Variable 6  =  [5.94626333]
# Variable 7  =  [-1.06923211]
# Variable 8  =  [2.10621773]
# error =  1,055.9591245543081
#
#
# Epoch 1000 :
#  Bias =  [[6.37581802]]
# Variable 1  =  [8.30744946]
# Variable 2  =  [3.90271676]
# Variable 3  =  [1.55135001]
# Variable 4  =  [-0.64178312]
# Variable 5  =  [-0.36364216]
# Variable 6  =  [5.94192141]
# Variable 7  =  [-1.09693228]
# Variable 8  =  [2.06235382]
# error =  985.1011144383602

# %% [markdown]
# ### Results from Model 5
# <img src="lr0.000001.png">

# %% [markdown]
# ## Summary for all error curves
#
# <img src="lr_all.png">

# %% [markdown]
# As we can see in the graph, the lowest error curve comes from the **Model 3** which has a learning rate of 0.0001. The results for this run are the following:
#
# Epoch 1000 :
# - Bias =  6.25387207
# - Variable 1  =  8.24033148
# - Variable 2  =  3.26574454
# - Variable 3  =  1.48943308
# - Variable 4  =  -0.12588394
# - Variable 5  =  -0.70471011
# - Variable 6  =  5.51034161
# - Variable 7  =  -0.63110015
# - Variable 8  =  -0.06510924
# - error =  23.286449037780255
#
# The formula goes as follows:
#
# - VA = Volatile Acidity
# - A = Alcohol
#
# $$ y = 6.25 + 8.24VA + 3.27A + 1.49VA^2 - 0.13A^2 - 0.70(VA)(A) + 5.51(VA^2)(A) - 0.63(VA)(A^2) - 0.65(VA^2)(A^2) $$
